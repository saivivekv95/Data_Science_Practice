# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/vivek/Downloads/archive (8)/car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df['Owner'].value_counts()
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
final_dataset = df[['Year','Selling_Price','Present_Price','Kms_Driven','Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
final_dataset['Current_Year'] = 2020

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year
# 0         Manual      0          2020
# 1         Manual      0          2020
# 2         Manual      0          2020
# 3         Manual      0          2020
# 4         Manual      0          2020
# ..           ...    ...           ...
# 296       Manual      0          2020
# 297       Manual      0          2020
# 298       Manual      0          2020
# 299       Manual      0          2020
# 300       Manual      0          2020
#
# [301 rows x 9 columns]

# %%
final_dataset['No_years'] = final_dataset['Current_Year']-final_dataset['Year']

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year  No_years
# 0         Manual      0          2020         6
# 1         Manual      0          2020         7
# 2         Manual      0          2020         3
# 3         Manual      0          2020         9
# 4         Manual      0          2020         6
# ..           ...    ...           ...       ...
# 296       Manual      0          2020         4
# 297       Manual      0          2020         5
# 298       Manual      0          2020        11
# 299       Manual      0          2020         3
# 300       Manual      0          2020         4
#
# [301 rows x 10 columns]

# %%
final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year  No_years
# 0         Manual      0          2020         6
# 1         Manual      0          2020         7
# 2         Manual      0          2020         3
# 3         Manual      0          2020         9
# 4         Manual      0          2020         6
# ..           ...    ...           ...       ...
# 296       Manual      0          2020         4
# 297       Manual      0          2020         5
# 298       Manual      0          2020        11
# 299       Manual      0          2020         3
# 300       Manual      0          2020         4
#
# [301 rows x 9 columns]

# %%
final_dataset.drop(['Current_Year'],axis=1,inplace=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No_years
# 0         Manual      0         6
# 1         Manual      0         7
# 2         Manual      0         3
# 3         Manual      0         9
# 4         Manual      0         6
# ..           ...    ...       ...
# 296       Manual      0         4
# 297       Manual      0         5
# 298       Manual      0        11
# 299       Manual      0         3
# 300       Manual      0         4
#
# [301 rows x 8 columns]

# %%
final_dataset = pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_years  \
# 0             3.35           5.59       27000      0         6
# 1             4.75           9.54       43000      0         7
# 2             7.25           9.85        6900      0         3
# 3             2.85           4.15        5200      0         9
# 4             4.60           6.87       42450      0         6
# ..             ...            ...         ...    ...       ...
# 296           9.50          11.60       33988      0         4
# 297           4.00           5.90       60000      0         5
# 298           3.35          11.00       87934      0        11
# 299          11.50          12.50        9000      0         3
# 300           5.30           5.90        5464      0         4
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# 2                   0                 1                       0
# 3                   0                 1                       0
# 4                   1                 0                       0
# ..                ...               ...                     ...
# 296                 1                 0                       0
# 297                 0                 1                       0
# 298                 0                 1                       0
# 299                 1                 0                       0
# 300                 0                 1                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [301 rows x 9 columns]

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# No_years                    -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         No_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# Kms_Driven              0.524342          0.172515         -0.172874
# Owner                   0.182104         -0.053469          0.055687
# No_years                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel       -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol        0.059959         -0.979648          1.000000
# Seller_Type_Individual  0.039896         -0.350467          0.358321
# Transmission_Manual    -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# No_years                              0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(final_dataset)

# %%
corrmat = final_dataset.corr()
top_corr_features = corrmat.index
plt.figure(figsize = (20,20))
g= sns.heatmap(final_dataset[top_corr_features].corr(),annot=True)

# %%
top_corr_features
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'No_years',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  No_years  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
X=final_dataset.iloc[:,1:]
y = final_dataset.iloc[:,0]

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  No_years  Fuel_Type_Diesel  \
# 0             5.59       27000      0         6                 0
# 1             9.54       43000      0         7                 1
# 2             9.85        6900      0         3                 0
# 3             4.15        5200      0         9                 0
# 4             6.87       42450      0         6                 1
# ..             ...         ...    ...       ...               ...
# 296          11.60       33988      0         4                 1
# 297           5.90       60000      0         5                 0
# 298          11.00       87934      0        11                 0
# 299          12.50        9000      0         3                 1
# 300           5.90        5464      0         4                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# 1                   0                       0                    1
# 2                   1                       0                    1
# 3                   1                       0                    1
# 4                   0                       0                    1
# ..                ...                     ...                  ...
# 296                 0                       0                    1
# 297                 1                       0                    1
# 298                 1                       0                    1
# 299                 0                       0                    1
# 300                 1                       0                    1
#
# [301 rows x 8 columns]

# %%
from sklearn.ensemble import ExtraTreesRegressor
model= ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.37917627 0.04332748 0.00039816 0.07559526 0.2287413  0.01047445
#  0.12690719 0.13537989]

# %%
feat_importances =pd.Series(model.feature_importances_,index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
y_train
# Out:
# 70      3.95
# 161     0.45
# 271     3.00
# 22      4.40
# 149     0.51
#        ...
# 102     1.65
# 53     16.00
# 191     0.20
# 229     3.10
# 147     0.55
# Name: Selling_Price, Length: 240, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import numpy as np
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
max_features=['auto','sqrt','log2']
max_depth = [int(x) for x in np.linspace(5,30,num=6)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf = [1,2,7,10]

# %%
random_grid={'n_estimators':n_estimators,
            'max_features':max_features,
            'max_depth':max_depth,
           'min_samples_split':min_samples_split,
           'min_samples_leaf':min_samples_leaf }
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 7, 10]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 7, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10, total=   0.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=7, max_features=auto, max_depth=10, total=   0.5s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30, total=   0.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30, total=   0.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30, total=   0.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30, total=   0.3s
# [CV] n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30
# [CV]  n_estimators=500, min_samples_split=100, min_samples_leaf=7, max_features=auto, max_depth=30, total=   0.3s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25, total=   0.7s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25, total=   0.6s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25, total=   0.8s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25, total=   0.5s
# [CV] n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=10, min_samples_leaf=10, max_features=auto, max_depth=25, total=   0.6s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=15, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25, total=   0.1s
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=log2, max_depth=25, total=   0.1s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   0.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   0.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   0.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   0.2s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=1, max_features=sqrt, max_depth=25, total=   0.2s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25, total=   0.3s
# [CV] n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25
# [CV]  n_estimators=400, min_samples_split=15, min_samples_leaf=1, max_features=auto, max_depth=25, total=   0.3s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5, total=   0.8s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5, total=   0.8s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5, total=   0.8s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5, total=   0.7s
# [CV] n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=2, min_samples_leaf=7, max_features=auto, max_depth=5, total=   0.7s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.5s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.5s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.5s
# [CV] n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15
# [CV]  n_estimators=600, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=15, total=   0.4s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10, total=   0.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10, total=   0.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10, total=   0.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10, total=   0.1s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=10, total=   0.1s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   20.9s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 7, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions = rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 3.76251667,  0.86065   ,  6.01015   , 20.3883    ,  4.16830116,
#        21.2938    ,  5.26015926,  1.13137222,  6.23551944,  5.67635556,
#        10.49373333,  0.96415833,  3.43238843,  3.16258333,  7.40745   ,
#         5.45983333,  8.271     , 10.25653333,  5.19315139,  1.08475   ,
#         6.22895833,  0.74158333,  6.8654    ,  6.04866667,  4.58546181,
#         4.58293333,  0.52182667,  0.63641667,  0.93405   ,  2.71468333,
#         4.35283333,  3.815     ,  0.64089444,  7.03051667,  0.47866667,
#         0.60454933,  0.61898333,  3.77226667,  7.6307    ,  0.61428333,
#         1.23861667,  4.23538548,  3.32881806,  0.56425583,  5.14351667,
#         3.67211667,  4.57418333, 20.13791667,  5.06529028,  0.2297    ,
#         0.5680375 ,  4.98307222,  0.46255556,  4.54653912,  4.9327875 ,
#         6.05466667,  7.61546875,  0.62160349, 11.53881667, 13.11868333,
#        10.45991667])

# %%
sns.distplot(y_test - predictions)
# Out:
# <AxesSubplot:xlabel='Selling_Price'>

# %%
plt.scatter(y_test,predictions)

# %%
import pickle
file = open('random_forest_regression_model.pkl','wb')

#dump information to that file
pickle.dump(rf_random,file)
